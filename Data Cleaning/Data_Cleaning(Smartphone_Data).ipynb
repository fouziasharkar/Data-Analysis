# %% [markdown]
# <a href="https://colab.research.google.com/github/fouziasharkar/Data-Analysis/blob/main/Data_Cleaning(Smartphone_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/smartphones - smartphones.csv')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
# 20. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df1 = df.copy()

# %%
df1['price']
# Out:
# 0       ₹54,999
# 1       ₹19,989
# 2       ₹16,499
# 3       ₹14,999
# 4       ₹24,999
#          ...
# 1015    ₹34,990
# 1016    ₹14,990
# 1017    ₹28,990
# 1018    ₹19,990
# 1019    ₹24,990
# Name: price, Length: 1020, dtype: object

# %%
#converting price column to string
df1['price'] = df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
# when opening the dataset in excel index starts from 2. Adjusting to match the manually choosen row numbers
df1 = df1.reset_index()

# %%
df1['index'] = df1['index'] + 2

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
#all problematic rows
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 988                                            Dual Sim
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1000                                           Dual Sim
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111           Bionic A14, Hexa Core, 3.1 GHz Processor
# 149           Bionic A14, Hexa Core, 3.1 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# ...                                                ...
# 954      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 988                            8 MB RAM, 16 MB inbuilt
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
# 1000                                             No 3G
# 1014   Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram  \
# 98    12 GB RAM, 256 GB inbuilt
# 111     4 GB RAM, 64 GB inbuilt
# 149     4 GB RAM, 64 GB inbuilt
# 155    4 GB RAM, 512 MB inbuilt
# 159   12 GB RAM, 256 GB inbuilt
# ...                         ...
# 954   12 GB RAM, 512 GB inbuilt
# 988            1200 mAh Battery
# 993    8 GB RAM, 512 GB inbuilt
# 1000                    No Wifi
# 1014  12 GB RAM, 256 GB inbuilt
#
#                                                 battery  \
# 98              4600 mAh Battery with 66W Fast Charging
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                                    1450 mAh Battery
# 159             4520 mAh Battery with 67W Fast Charging
# ...                                                 ...
# 954             4600 mAh Battery with 66W Fast Charging
# 988                    2.4 inches, 240 x 320 px Display
# 993             4500 mAh Battery with 55W Fast Charging
# 1000                           32 MB RAM, 32 MB inbuilt
# 1014            4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# ...                                                 ...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 988                                  0.3 MP Rear Camera
# 993                    8 inches, 2200 x 2480 px Display
# 1000                                    800 mAh Battery
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                  camera  \
# 98                     Foldable Display
# 111           Memory Card Not Supported
# 149           Memory Card Not Supported
# 155                        Dual Display
# 159      Foldable Display, Dual Display
# ...                                 ...
# 954                    Foldable Display
# 988   Memory Card Supported, upto 32 GB
# 993                    Foldable Display
# 1000  1.77 inches, 240 x 320 px Display
# 1014                   Foldable Display
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111                                             iOS v14
# 149                                             iOS v14
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# ...                                                 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 988                                           Bluetooth
# 993                              48 MP Quad Rear Camera
# 1000                                       Dual Display
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 98                          Android v12
# 111                         No FM Radio
# 149                         No FM Radio
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# ...                                 ...
# 954                         Android v12
# 988                             Browser
# 993   Memory Card (Hybrid), upto 256 GB
# 1000                 1.3 MP Rear Camera
# 1014                        Android v12
#
# [68 rows x 12 columns]

# %%
# all problematic rows who have problems in every column.
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 647                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 657                       Single Sim    32 MB RAM, 32 MB inbuilt
# 665                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 748       Dual Sim, 4G, VoLTE, Wi-Fi            2000 mAh Battery
# 757                         Dual Sim    52 MB RAM, 32 MB inbuilt
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                       No 3G
# 882                 Dual Sim, 3G, 4G                     No Wifi
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 927                       Single Sim                     No Wifi
# 930          Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 1000                        Dual Sim                       No 3G
#
#                                    ram                            battery  \
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645   3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                   1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                   1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 882                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 925                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera  \
# 640                      No Rear Camera   Memory Card Supported, upto 32 GB
# 645   Memory Card Supported, upto 32 GB                          Kaios v3.0
# 647                      No Rear Camera   Memory Card Supported, upto 32 GB
# 657                      No Rear Camera                         No FM Radio
# 665                      No Rear Camera   Memory Card Supported, upto 32 GB
# 748   Memory Card Supported, upto 64 GB                           Bluetooth
# 757                      No Rear Camera   Memory Card Supported, upto 16 GB
# 817                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 882                    1450 mAh Battery    2.4 inches, 240 x 320 px Display
# 925                    2 MP Rear Camera   Memory Card Supported, upto 32 GB
# 927                      No Rear Camera                         No FM Radio
# 930                  0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1000                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                     card                                 os
# 640            Bluetooth                                NaN
# 645            Bluetooth                                NaN
# 647                  NaN                                NaN
# 657            Bluetooth                                NaN
# 665            Bluetooth                                NaN
# 748              Browser                                NaN
# 757            Bluetooth                                NaN
# 817   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 882   0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925            Bluetooth                            Browser
# 927                  NaN                                NaN
# 930            Bluetooth                            Browser
# 1000        Dual Display                 1.3 MP Rear Camera

# %%
#a observation is phones whose price<3400 are not smartphones. Our analysis is on smartphones. so excluding this rows.
df1 = df1[df1['price'] >= 3400]

# %%
df1.head()
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
# 3      5       Motorola Moto G62 5G  14999    81.0
# 4      6         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
#processor column

# these are still feature phones. So dropping it
df1[df1['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 857                   2 MP Rear Camera              Memory Card Supported
# 882                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 925                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 645           Bluetooth                                NaN
# 857           Bluetooth                                NaN
# 882  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925           Bluetooth                            Browser

# %%
df1.drop([645,857,882,925],inplace=True)

# %%
# ram column

df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 582                             1450 mAh Battery
#
#                                                 camera  \
# 439                          Memory Card Not Supported
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 582                   2.8 inches, 240 x 320 px Display
#
#                                   card                                 os
# 439                            iOS v15                        No FM Radio
# 483  Memory Card (Hybrid), upto 256 GB                   Hongmeng OS v3.0
# 582                 0.3 MP Rear Camera  Memory Card Supported, upto 32 GB

# %%
#582 row phone is a feature phone
df1.drop(582,inplace=True)

# %%
#battery column

df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 376                         Dual Sim, 3G, 4G
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 754                                    Wi-Fi
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor
# 376                                     No Wifi
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                 Bionic  A16
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor
# 754                               32 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 853    Bionic A14, Hexa Core, 3.1 GHz Processor
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                                  ram  \
# 111          4 GB RAM, 64 GB inbuilt
# 149          4 GB RAM, 64 GB inbuilt
# 307         4 GB RAM, 128 GB inbuilt
# 363         4 GB RAM, 128 GB inbuilt
# 376                      Unisoc T107
# 439                    64 GB inbuilt
# 448         8 GB RAM, 128 GB inbuilt
# 628         6 GB RAM, 512 GB inbuilt
# 754  4 inches, 640 x 1136 px Display
# 762                    64 GB inbuilt
# 853         6 GB RAM, 256 GB inbuilt
# 913         4 GB RAM, 256 GB inbuilt
# 914         4 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 376                          48 MB RAM, 128 MB inbuilt
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 754                    8 MP Rear & 1.2 MP Front Camera
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 376                                   1450 mAh Battery
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 754                                            iOS v12
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                                camera          card                  os
# 111         Memory Card Not Supported       iOS v14         No FM Radio
# 149         Memory Card Not Supported       iOS v14         No FM Radio
# 307         Memory Card Not Supported       iOS v14         No FM Radio
# 363         Memory Card Not Supported       iOS v14         No FM Radio
# 376  2.8 inches, 240 x 320 px Display  Dual Display  0.3 MP Rear Camera
# 439         Memory Card Not Supported       iOS v15         No FM Radio
# 448         Memory Card Not Supported       iOS v15         No FM Radio
# 628         Memory Card Not Supported     iOS v14.0         No FM Radio
# 754                       No FM Radio     Bluetooth             Browser
# 762         Memory Card Not Supported       iOS v16         No FM Radio
# 853         Memory Card Not Supported     iOS v14.0         No FM Radio
# 913         Memory Card Not Supported       iOS v14         No FM Radio
# 914         Memory Card Not Supported       iOS v14         No FM Radio

# %%
# apple ipod and feature phone

df1.drop([376,754],inplace=True)

# %%
temp_df = df1[df1['index'].isin(battery_rows)]
temp_df
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 853    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                         camera       card           os
# 111  Memory Card Not Supported    iOS v14  No FM Radio
# 149  Memory Card Not Supported    iOS v14  No FM Radio
# 307  Memory Card Not Supported    iOS v14  No FM Radio
# 363  Memory Card Not Supported    iOS v14  No FM Radio
# 439  Memory Card Not Supported    iOS v15  No FM Radio
# 448  Memory Card Not Supported    iOS v15  No FM Radio
# 628  Memory Card Not Supported  iOS v14.0  No FM Radio
# 762  Memory Card Not Supported    iOS v16  No FM Radio
# 853  Memory Card Not Supported  iOS v14.0  No FM Radio
# 913  Memory Card Not Supported    iOS v14  No FM Radio
# 914  Memory Card Not Supported    iOS v14  No FM Radio

# %%
#for these rows no info about battery so it shifted the info. so performing row shift.

x = temp_df.iloc[:,7:].shift(1,axis=1)
x
# Out:
#     battery                                            display  \
# 111    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 149    None                 5.4 inches, 1080 x 2340 px Display
# 307    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 363    None                 5.4 inches, 1080 x 2340 px Display
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 853    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                           card         os
# 111  Memory Card Not Supported    iOS v14
# 149  Memory Card Not Supported    iOS v14
# 307  Memory Card Not Supported    iOS v14
# 363  Memory Card Not Supported    iOS v14
# 439  Memory Card Not Supported    iOS v15
# 448  Memory Card Not Supported    iOS v15
# 628  Memory Card Not Supported  iOS v14.0
# 762  Memory Card Not Supported    iOS v16
# 853  Memory Card Not Supported  iOS v14.0
# 913  Memory Card Not Supported    iOS v14
# 914  Memory Card Not Supported    iOS v14

# %%
df1.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 853    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#     battery                                            display  \
# 111    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 149    None                 5.4 inches, 1080 x 2340 px Display
# 307    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 363    None                 5.4 inches, 1080 x 2340 px Display
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 853    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                           card         os
# 111  Memory Card Not Supported    iOS v14
# 149  Memory Card Not Supported    iOS v14
# 307  Memory Card Not Supported    iOS v14
# 363  Memory Card Not Supported    iOS v14
# 439  Memory Card Not Supported    iOS v15
# 448  Memory Card Not Supported    iOS v15
# 628  Memory Card Not Supported  iOS v14.0
# 762  Memory Card Not Supported    iOS v16
# 853  Memory Card Not Supported  iOS v14.0
# 913  Memory Card Not Supported    iOS v14
# 914  Memory Card Not Supported    iOS v14

# %%
#camera roe
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 439     441                    Apple iPhone SE 3 2022   43900     NaN
# 448     450                       Apple iPhone 15 Pro  130990    75.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 613     615                              Oukitel WP21   22990    82.0
# 628     630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 682     684                              LG V60 ThinQ   79990     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 762     764                         Apple iPhone SE 4   49990    60.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 853     855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 856     858                   Samsung Galaxy A01 Core    4999     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 913     915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916                   Apple iPhone 12 (256GB)   67999    76.0
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 271                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 363             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 628             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 853             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 856                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 913             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor  \
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111            Bionic A14, Hexa Core, 3.1 GHz Processor
# 149            Bionic A14, Hexa Core, 3.1 GHz Processor
# 155      Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 271       Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 307            Bionic A14, Hexa Core, 3.1 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363            Bionic A14, Hexa Core, 3.1 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 439          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                         Bionic  A16
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 628            Bionic A14, Hexa Core, 3.1 GHz Processor
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 762          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 853            Bionic A14, Hexa Core, 3.1 GHz Processor
# 856               (28 nm), Quad Core, 1.5 GHz Processor
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 913            Bionic A14, Hexa Core, 3.1 GHz Processor
# 914            Bionic A14, Hexa Core, 3.1 GHz Processor
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram                                  battery  \
# 98    12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 111     4 GB RAM, 64 GB inbuilt                                     None
# 149     4 GB RAM, 64 GB inbuilt                                     None
# 155    4 GB RAM, 512 MB inbuilt                         1450 mAh Battery
# 159   12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 236   12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 271    512 MB RAM, 4 GB inbuilt                         1500 mAh Battery
# 306    8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 307    4 GB RAM, 128 GB inbuilt                                     None
# 321   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 322    8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 363    4 GB RAM, 128 GB inbuilt                                     None
# 365    8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392    8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 439               64 GB inbuilt                                     None
# 448    8 GB RAM, 128 GB inbuilt                                     None
# 482   12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 504    8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 569   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 570    8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613   12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 628    6 GB RAM, 512 GB inbuilt                                     None
# 682    8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 703    8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 709    8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 721   16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726    8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 762               64 GB inbuilt                                     None
# 790   12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 844     2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 853    6 GB RAM, 256 GB inbuilt                                     None
# 856     1 GB RAM, 16 GB inbuilt                         3000 mAh Battery
# 894    8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 913    4 GB RAM, 256 GB inbuilt                                     None
# 914    4 GB RAM, 256 GB inbuilt                                     None
# 943     12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 954   12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 993    8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 1014  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 271                    2.8 inches, 240 x 320 px Display
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 363                  5.4 inches, 1080 x 2340 px Display
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 762                   6.1 inches, 750 x 1580 px Display
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 844                      4 inches, 480 x 640 px Display
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 856                   5.3 inches, 720 x 1480 px Display
# 894                  7.2 inches, 1440 x 1920 px Display
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 993                    8 inches, 2200 x 2480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                  camera  \
# 98                                     Foldable Display
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                                        Dual Display
# 159                      Foldable Display, Dual Display
# 236                      Foldable Display, Dual Display
# 271                                        Dual Display
# 306                      Foldable Display, Dual Display
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 321                      Foldable Display, Dual Display
# 322                      Foldable Display, Dual Display
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 365                      Foldable Display, Dual Display
# 392                      Foldable Display, Dual Display
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 482                      Foldable Display, Dual Display
# 504                      Foldable Display, Dual Display
# 569                      Foldable Display, Dual Display
# 570                                        Dual Display
# 613                                        Dual Display
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 682                                        Dual Display
# 703                      Foldable Display, Dual Display
# 709                                        Dual Display
# 721                                        Dual Display
# 726                                    Foldable Display
# 762                   12 MP Rear & 10.8 MP Front Camera
# 790                      Foldable Display, Dual Display
# 844                                        Dual Display
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 856                       8 MP Rear & 5 MP Front Camera
# 894                      Foldable Display, Dual Display
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 943                      Foldable Display, Dual Display
# 954                                    Foldable Display
# 993                                    Foldable Display
# 1014                                   Foldable Display
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111                           Memory Card Not Supported
# 149                           Memory Card Not Supported
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 271                                    2 MP Rear Camera
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307                           Memory Card Not Supported
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                           Memory Card Not Supported
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                           Memory Card Not Supported
# 448                           Memory Card Not Supported
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628                           Memory Card Not Supported
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 762                           Memory Card Not Supported
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853                           Memory Card Not Supported
# 856                               Memory Card Supported
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913                           Memory Card Not Supported
# 914                           Memory Card Not Supported
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 111                              iOS v14
# 149                              iOS v14
# 155    Memory Card Supported, upto 32 GB
# 159            Memory Card Not Supported
# 236                          Android v12
# 271                Memory Card Supported
# 306            Memory Card Not Supported
# 307                              iOS v14
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 363                              iOS v14
# 365            Memory Card Not Supported
# 392            Memory Card Not Supported
# 439                              iOS v15
# 448                              iOS v15
# 482                          Android v12
# 504            Memory Card Not Supported
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 613                 Memory Card (Hybrid)
# 628                            iOS v14.0
# 682      Memory Card (Hybrid), upto 2 TB
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 762                              iOS v16
# 790                          Android v10
# 844   Memory Card Supported, upto 128 GB
# 853                            iOS v14.0
# 856                          Android v10
# 894   Memory Card Supported, upto 256 GB
# 913                              iOS v14
# 914                              iOS v14
# 943                          Android v12
# 954                          Android v12
# 993    Memory Card (Hybrid), upto 256 GB
# 1014                         Android v12

# %%
#droping feature phones

df1.drop([155, 271],inplace=True)

# %%
temp_df = df1[df1['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]
temp_df
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 613     615                              Oukitel WP21   22990    82.0
# 682     684                              LG V60 ThinQ   79990     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor  \
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram                                  battery  \
# 98    12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 159   12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 236   12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 306    8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 321   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 322    8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365    8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392    8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 482   12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 504    8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 569   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 570    8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613   12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682    8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 703    8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 709    8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 721   16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726    8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 790   12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 844     2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 894    8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 943     12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 954   12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 993    8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 1014  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 844                      4 inches, 480 x 640 px Display
# 894                  7.2 inches, 1440 x 1920 px Display
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 993                    8 inches, 2200 x 2480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                               camera  \
# 98                  Foldable Display
# 159   Foldable Display, Dual Display
# 236   Foldable Display, Dual Display
# 306   Foldable Display, Dual Display
# 321   Foldable Display, Dual Display
# 322   Foldable Display, Dual Display
# 365   Foldable Display, Dual Display
# 392   Foldable Display, Dual Display
# 482   Foldable Display, Dual Display
# 504   Foldable Display, Dual Display
# 569   Foldable Display, Dual Display
# 570                     Dual Display
# 613                     Dual Display
# 682                     Dual Display
# 703   Foldable Display, Dual Display
# 709                     Dual Display
# 721                     Dual Display
# 726                 Foldable Display
# 790   Foldable Display, Dual Display
# 844                     Dual Display
# 894   Foldable Display, Dual Display
# 943   Foldable Display, Dual Display
# 954                 Foldable Display
# 993                 Foldable Display
# 1014                Foldable Display
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 159            Memory Card Not Supported
# 236                          Android v12
# 306            Memory Card Not Supported
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 365            Memory Card Not Supported
# 392            Memory Card Not Supported
# 482                          Android v12
# 504            Memory Card Not Supported
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 613                 Memory Card (Hybrid)
# 682      Memory Card (Hybrid), upto 2 TB
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 790                          Android v10
# 844   Memory Card Supported, upto 128 GB
# 894   Memory Card Supported, upto 256 GB
# 943                          Android v12
# 954                          Android v12
# 993    Memory Card (Hybrid), upto 256 GB
# 1014                         Android v12

# %%
df1.loc[temp_df.index,'camera']
# Out:
# 98                    Foldable Display
# 159     Foldable Display, Dual Display
# 236     Foldable Display, Dual Display
# 306     Foldable Display, Dual Display
# 321     Foldable Display, Dual Display
# 322     Foldable Display, Dual Display
# 365     Foldable Display, Dual Display
# 392     Foldable Display, Dual Display
# 482     Foldable Display, Dual Display
# 504     Foldable Display, Dual Display
# 569     Foldable Display, Dual Display
# 570                       Dual Display
# 613                       Dual Display
# 682                       Dual Display
# 703     Foldable Display, Dual Display
# 709                       Dual Display
# 721                       Dual Display
# 726                   Foldable Display
# 790     Foldable Display, Dual Display
# 844                       Dual Display
# 894     Foldable Display, Dual Display
# 943     Foldable Display, Dual Display
# 954                   Foldable Display
# 993                   Foldable Display
# 1014                  Foldable Display
# Name: camera, dtype: object

# %%
df1.loc[temp_df.index,'camera'] = temp_df['card'].values

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 439     441                    Apple iPhone SE 3 2022   43900     NaN
# 448     450                       Apple iPhone 15 Pro  130990    75.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 613     615                              Oukitel WP21   22990    82.0
# 628     630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 682     684                              LG V60 ThinQ   79990     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 762     764                         Apple iPhone SE 4   49990    60.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 853     855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 856     858                   Samsung Galaxy A01 Core    4999     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 913     915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916                   Apple iPhone 12 (256GB)   67999    76.0
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 363             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 628             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 853             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 856                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 913             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor  \
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111            Bionic A14, Hexa Core, 3.1 GHz Processor
# 149            Bionic A14, Hexa Core, 3.1 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 307            Bionic A14, Hexa Core, 3.1 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363            Bionic A14, Hexa Core, 3.1 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 439          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                         Bionic  A16
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 628            Bionic A14, Hexa Core, 3.1 GHz Processor
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 762          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 853            Bionic A14, Hexa Core, 3.1 GHz Processor
# 856               (28 nm), Quad Core, 1.5 GHz Processor
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 913            Bionic A14, Hexa Core, 3.1 GHz Processor
# 914            Bionic A14, Hexa Core, 3.1 GHz Processor
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram                                  battery  \
# 98    12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 111     4 GB RAM, 64 GB inbuilt                                     None
# 149     4 GB RAM, 64 GB inbuilt                                     None
# 159   12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 236   12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 306    8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 307    4 GB RAM, 128 GB inbuilt                                     None
# 321   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 322    8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 363    4 GB RAM, 128 GB inbuilt                                     None
# 365    8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392    8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 439               64 GB inbuilt                                     None
# 448    8 GB RAM, 128 GB inbuilt                                     None
# 482   12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 504    8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 569   12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 570    8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613   12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 628    6 GB RAM, 512 GB inbuilt                                     None
# 682    8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 703    8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 709    8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 721   16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726    8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 762               64 GB inbuilt                                     None
# 790   12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 844     2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 853    6 GB RAM, 256 GB inbuilt                                     None
# 856     1 GB RAM, 16 GB inbuilt                         3000 mAh Battery
# 894    8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 913    4 GB RAM, 256 GB inbuilt                                     None
# 914    4 GB RAM, 256 GB inbuilt                                     None
# 943     12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 954   12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 993    8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 1014  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 363                  5.4 inches, 1080 x 2340 px Display
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 762                   6.1 inches, 750 x 1580 px Display
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 844                      4 inches, 480 x 640 px Display
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 856                   5.3 inches, 720 x 1480 px Display
# 894                  7.2 inches, 1440 x 1920 px Display
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 993                    8 inches, 2200 x 2480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                  camera  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 762                   12 MP Rear & 10.8 MP Front Camera
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 856                       8 MP Rear & 5 MP Front Camera
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111                           Memory Card Not Supported
# 149                           Memory Card Not Supported
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307                           Memory Card Not Supported
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                           Memory Card Not Supported
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                           Memory Card Not Supported
# 448                           Memory Card Not Supported
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628                           Memory Card Not Supported
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 762                           Memory Card Not Supported
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                       5 MP Rear & 2 MP Front Camera
# 853                           Memory Card Not Supported
# 856                               Memory Card Supported
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913                           Memory Card Not Supported
# 914                           Memory Card Not Supported
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 993                              48 MP Quad Rear Camera
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 111                              iOS v14
# 149                              iOS v14
# 159            Memory Card Not Supported
# 236                          Android v12
# 306            Memory Card Not Supported
# 307                              iOS v14
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 363                              iOS v14
# 365            Memory Card Not Supported
# 392            Memory Card Not Supported
# 439                              iOS v15
# 448                              iOS v15
# 482                          Android v12
# 504            Memory Card Not Supported
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 613                 Memory Card (Hybrid)
# 628                            iOS v14.0
# 682      Memory Card (Hybrid), upto 2 TB
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 762                              iOS v16
# 790                          Android v10
# 844   Memory Card Supported, upto 128 GB
# 853                            iOS v14.0
# 856                          Android v10
# 894   Memory Card Supported, upto 256 GB
# 913                              iOS v14
# 914                              iOS v14
# 943                          Android v12
# 954                          Android v12
# 993    Memory Card (Hybrid), upto 256 GB
# 1014                         Android v12

# %%
#card column

df1['card'].value_counts().reset_index()
# Out:
#                                                  card  count
# 0                    Memory Card Supported, upto 1 TB    171
# 1                           Memory Card Not Supported    123
# 2                                         Android v12    107
# 3                  Memory Card Supported, upto 512 GB    105
# 4                     Memory Card (Hybrid), upto 1 TB     91
# 5                               Memory Card Supported     89
# 6                  Memory Card Supported, upto 256 GB     87
# 7                                         Android v13     46
# 8                                         Android v11     41
# 9                                Memory Card (Hybrid)     30
# 10                  Memory Card (Hybrid), upto 256 GB     13
# 11                                        Android v10     11
# 12                  Memory Card (Hybrid), upto 512 GB     11
# 13                 Memory Card Supported, upto 128 GB      6
# 14                   Memory Card Supported, upto 2 TB      5
# 15                  Memory Card Supported, upto 32 GB      4
# 16                   Memory Card (Hybrid), upto 64 GB      3
# 17                  Memory Card (Hybrid), upto 128 GB      3
# 18                                 Android v9.0 (Pie)      2
# 19  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...      2
# 20  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...      2
# 21        50 MP + 8 MP Dual Rear & 32 MP Front Camera      2
# 22       12 MP + 12 MP Dual Rear & 10 MP Front Camera      2
# 23               50 MP Quad Rear & 16 MP Front Camera      2
# 24  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...      1
# 25                             48 MP Quad Rear Camera      1
# 26                                          HarmonyOS      1
# 27                    Memory Card (Hybrid), upto 2 TB      1
# 28                      5 MP Rear & 2 MP Front Camera      1
# 29  108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...      1
# 30                                     HarmonyOS v2.0      1
# 31  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...      1
# 32  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...      1
# 33  64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...      1
# 34  50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...      1
# 35                                            iOS v13      1
# 36  50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...      1
# 37                                      Android v10.0      1
# 38  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...      1
# 39                                            iOS v10      1
# 40  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...      1
# 41  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...      1
# 42                Memory Card Supported, upto 1000 GB      1
# 43  50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera      1
# 44  64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front...      1
# 45                                      Android v12.1      1
# 46  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...      1
# 47  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...      1

# %%
#onek gulo camera resolution ase. so cleaning it first

temp_df = df1[df1['card'].str.contains('MP')]

# %%
df1.loc[temp_df.index,'card']
# Out:
# 69      64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front...
# 98                   50 MP Quad Rear & 16 MP Front Camera
# 159     50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236     50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306          12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 321     50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322     64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 482     50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504          12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569     12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570     64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613     64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682     64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703     50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709     64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721     50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726     50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 790     108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 844                         5 MP Rear & 2 MP Front Camera
# 894     64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 943     50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                  50 MP Quad Rear & 16 MP Front Camera
# 993                                48 MP Quad Rear Camera
# 1014    50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
# Name: card, dtype: object

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts().reset_index()
# Out:
#                                    card  count
# 0      Memory Card Supported, upto 1 TB    171
# 1             Memory Card Not Supported    149
# 2                           Android v12    107
# 3    Memory Card Supported, upto 512 GB    105
# 4       Memory Card (Hybrid), upto 1 TB     91
# 5                 Memory Card Supported     89
# 6    Memory Card Supported, upto 256 GB     87
# 7                           Android v13     46
# 8                           Android v11     41
# 9                  Memory Card (Hybrid)     30
# 10    Memory Card (Hybrid), upto 256 GB     13
# 11    Memory Card (Hybrid), upto 512 GB     11
# 12                          Android v10     11
# 13   Memory Card Supported, upto 128 GB      6
# 14     Memory Card Supported, upto 2 TB      5
# 15    Memory Card Supported, upto 32 GB      4
# 16     Memory Card (Hybrid), upto 64 GB      3
# 17    Memory Card (Hybrid), upto 128 GB      3
# 18                   Android v9.0 (Pie)      2
# 19                        Android v12.1      1
# 20  Memory Card Supported, upto 1000 GB      1
# 21                              iOS v10      1
# 22                        Android v10.0      1
# 23                              iOS v13      1
# 24                       HarmonyOS v2.0      1
# 25      Memory Card (Hybrid), upto 2 TB      1
# 26                            HarmonyOS      1

# %%
#filtering datas who does not contain memory card
temp_df = df1[~df1['card'].str.contains('Memory Card')]
temp_df
# Out:
#       index                        model  price  rating  \
# 8        10              Nothing Phone 1  26749    85.0
# 9        11           OnePlus Nord 2T 5G  28999    84.0
# 12       14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17       19         OPPO Reno 9 Pro Plus  45999    86.0
# 18       20               OnePlus 10R 5G  32999    86.0
# ...     ...                          ...    ...     ...
# 1009   1011                Xiaomi Civi 3  32990    86.0
# 1011   1013                 Oppo Find X6  69990    89.0
# 1012   1014                    itel A23s   4787     NaN
# 1013   1015           Google Pixel 8 Pro  70990    80.0
# 1015   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 1009  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1011            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1012                            Dual Sim, 3G, 4G, Wi-Fi
# 1013            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                               processor  \
# 8     Snapdragon 778G Plus, Octa Core, 2.5 GHz Proce...
# 9           Dimensity  1300, Octa Core, 3 GHz Processor
# 12         Dimensity 1080, Octa Core, 2.6 GHz Processor
# 17     Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 18    Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# ...                                                 ...
# 1009       Dimensity 8200, Octa Core, 3.1 GHz Processor
# 1011    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1013              Google  Tensor 3, Octa Core Processor
# 1015      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
#
#                             ram                                    battery  \
# 8      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 33W Fast Charging
# 9      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 80W Fast Charging
# 12     6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 17    16 GB RAM, 256 GB inbuilt    4700 mAh Battery with 80W Fast Charging
# 18     8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# ...                         ...                                        ...
# 1009   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# 1011   8 GB RAM, 256 GB inbuilt   4700 mAh Battery with 120W Fast Charging
# 1012    2 GB RAM, 32 GB inbuilt                           3020 mAh Battery
# 1013  12 GB RAM, 256 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
#
#                                                 display  \
# 8     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 9     6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 12    6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 17    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 18    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1009  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 1011  6.73 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1012                     5 inches, 854 x 480 px Display
# 1013  6.73 inches, 1440 x 3120 px, 120 Hz Display wi...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
#
#                                                  camera         card  \
# 8          50 MP + 50 MP Dual Rear & 16 MP Front Camera  Android v12
# 9     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...  Android v12
# 12    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
# 17    50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...  Android v13
# 18    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
# ...                                                 ...          ...
# 1009  64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...  Android v13
# 1011  50 MP + 48 MP + 32 MP Triple Rear & 32 MP Fron...  Android v12
# 1012                                   2 MP Rear Camera  Android v11
# 1013  50 MP + 50 MP + 50 MP Triple Rear & 12 MP Fron...  Android v13
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
#
#                os
# 8     No FM Radio
# 9     No FM Radio
# 12    No FM Radio
# 17    No FM Radio
# 18      Bluetooth
# ...           ...
# 1009  No FM Radio
# 1011  No FM Radio
# 1012  No FM Radio
# 1013  No FM Radio
# 1015  No FM Radio
#
# [213 rows x 12 columns]

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
# os column

df1['os'].value_counts().reset_index()
# Out:
#                                     os  count
# 0                          Android v12    287
# 1                          Android v11    233
# 2                          No FM Radio    180
# 3                          Android v10     58
# 4                          Android v13     45
# 5                            Bluetooth     34
# 6                   Android v9.0 (Pie)     27
# 7                        Android v10.0     22
# 8                              iOS v16     15
# 9                              iOS v15     12
# 10                 Android v8.1 (Oreo)     10
# 11                             iOS v14      6
# 12           Memory Card Not Supported      6
# 13                 Android v8.0 (Oreo)      4
# 14                       Android v11.0      4
# 15                           iOS v15.0      3
# 16                             iOS v13      3
# 17     Memory Card (Hybrid), upto 2 TB      2
# 18   Memory Card (Hybrid), upto 256 GB      2
# 19           Android v5.1.1 (Lollipop)      2
# 20                        Harmony v2.0      2
# 21  Memory Card Supported, upto 256 GB      2
# 22          Android v6.0 (Marshmallow)      2
# 23                            EMUI v12      2
# 24                           iOS v14.0      2
# 25  Memory Card Supported, upto 128 GB      1
# 26                      HarmonyOS v2.0      1
# 27                             Android      1
# 28                    Hongmeng OS v4.0      1
# 29               Android v7.1 (Nougat)      1
# 30                             iOS v17      1
# 31                   RTOS (Series 30+)      1
# 32                Memory Card (Hybrid)      1
# 33     Pragati OS (Powered by Android)      1
# 34                    Hongmeng OS v3.0      1
# 35             Android v5.1 (Lollipop)      1
# 36             Android v4.4.2 (KitKat)      1
# 37                           iOS v12.3      1
# 38                       Android v12.1      1
# 39                           iOS v13.0      1
# 40                        HarmonyOS v2      1
# 41                    Android v9 (Pie)      1

# %%
df1[df1['os'].str.contains('Memory Card')]
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 721            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 844                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                              processor  \
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 504  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 570    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613            Helio G99, Octa Core, 2.2 GHz Processor
# 682     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 721  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 844         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 894      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram                                  battery  \
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 306   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 322   8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365   8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392   8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 504   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 570   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 721  16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 844    2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 993   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                display  \
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 322                 7.8 inches, 1440 x 1920 px Display
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 504  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 570                 6.8 inches, 1080 x 2460 px Display
# 613        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682  6.8 inches, 1080 x 2460 px Display with Punch ...
# 721        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 844                     4 inches, 480 x 640 px Display
# 894                 7.2 inches, 1440 x 1920 px Display
# 993                   8 inches, 2200 x 2480 px Display
#
#                                                 camera  \
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 306       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 504       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 570  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 721  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 993                             48 MP Quad Rear Camera
#
#                           card                                  os
# 159  Memory Card Not Supported           Memory Card Not Supported
# 306  Memory Card Not Supported           Memory Card Not Supported
# 322  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 365  Memory Card Not Supported           Memory Card Not Supported
# 392  Memory Card Not Supported           Memory Card Not Supported
# 504  Memory Card Not Supported           Memory Card Not Supported
# 570  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 613  Memory Card Not Supported                Memory Card (Hybrid)
# 682  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 721  Memory Card Not Supported           Memory Card Not Supported
# 726  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
# 844  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 894  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 993  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB

# %%
temp_df = df1[df1['os'].str.contains('Memory Card Supported')]
temp_df
# Out:
#      index                model   price  rating  \
# 322    324     Royole FlexPai 2  109999    87.0
# 844    846         CAT S22 Flip   14999     NaN
# 894    896  Royole FlexPai 3 5G  149999    87.0
#
#                                     sim  \
# 322  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 844    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                       ram  \
# 322  Snapdragon 865, Octa Core, 2.84 GHz Processor  8 GB RAM, 128 GB inbuilt
# 844     Qualcomm 215, Quad Core, 1.3 GHz Processor   2 GB RAM, 16 GB inbuilt
# 894  Snapdragon 888, Octa Core, 2.84 GHz Processor  8 GB RAM, 128 GB inbuilt
#
#               battery                             display  \
# 322  4450 mAh Battery  7.8 inches, 1440 x 1920 px Display
# 844  2000 mAh Battery      4 inches, 480 x 640 px Display
# 894  3360 mAh Battery  7.2 inches, 1440 x 1920 px Display
#
#                                                 camera  \
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
#
#                           card                                  os
# 322  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 844  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 894  Memory Card Not Supported  Memory Card Supported, upto 256 GB

# %%
temp_df.loc[temp_df.index,'card'] = temp_df['os'].values

# %%
df1.loc[temp_df.index,'card'] = temp_df['os'].values

# %%
temp_df
# Out:
#      index                model   price  rating  \
# 322    324     Royole FlexPai 2  109999    87.0
# 844    846         CAT S22 Flip   14999     NaN
# 894    896  Royole FlexPai 3 5G  149999    87.0
#
#                                     sim  \
# 322  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 844    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                       ram  \
# 322  Snapdragon 865, Octa Core, 2.84 GHz Processor  8 GB RAM, 128 GB inbuilt
# 844     Qualcomm 215, Quad Core, 1.3 GHz Processor   2 GB RAM, 16 GB inbuilt
# 894  Snapdragon 888, Octa Core, 2.84 GHz Processor  8 GB RAM, 128 GB inbuilt
#
#               battery                             display  \
# 322  4450 mAh Battery  7.8 inches, 1440 x 1920 px Display
# 844  2000 mAh Battery      4 inches, 480 x 640 px Display
# 894  3360 mAh Battery  7.2 inches, 1440 x 1920 px Display
#
#                                                 camera  \
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
#
#                                    card                                  os
# 322  Memory Card Supported, upto 256 GB  Memory Card Supported, upto 256 GB
# 844  Memory Card Supported, upto 128 GB  Memory Card Supported, upto 128 GB
# 894  Memory Card Supported, upto 256 GB  Memory Card Supported, upto 256 GB

# %%
temp_df = df1[df1['os'].str.contains("Hybrid")]
temp_df
# Out:
#      index             model   price  rating  \
# 570    572        LG Wing 5G   54999    89.0
# 613    615      Oukitel WP21   22990    82.0
# 682    684      LG V60 ThinQ   79990     NaN
# 726    728  Huawei Mate Xs 2  162990    89.0
# 993    995     Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            processor  \
# 570  Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613          Helio G99, Octa Core, 2.2 GHz Processor
# 682   Snapdragon  865, Octa Core, 2.84 GHz Processor
# 726    Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993        Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram                                  battery  \
# 570   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 726   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 993   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                display  \
# 570                 6.8 inches, 1080 x 2460 px Display
# 613        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682  6.8 inches, 1080 x 2460 px Display with Punch ...
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 993                   8 inches, 2200 x 2480 px Display
#
#                                                 camera  \
# 570  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 726  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 993                             48 MP Quad Rear Camera
#
#                           card                                 os
# 570  Memory Card Not Supported    Memory Card (Hybrid), upto 2 TB
# 613  Memory Card Not Supported               Memory Card (Hybrid)
# 682  Memory Card Not Supported    Memory Card (Hybrid), upto 2 TB
# 726  Memory Card Not Supported  Memory Card (Hybrid), upto 256 GB
# 993  Memory Card Not Supported  Memory Card (Hybrid), upto 256 GB

# %%
df1.loc[temp_df.index,'card'] = temp_df['os'].values

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]
temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 613                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 721            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 844                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 894                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                              processor  \
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 504  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 570    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 613            Helio G99, Octa Core, 2.2 GHz Processor
# 682     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 721  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 844         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 894      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                            ram                                  battery  \
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 306   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 322   8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365   8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392   8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 504   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 570   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 613  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 721  16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 844    2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 894   8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 993   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                display  \
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 322                 7.8 inches, 1440 x 1920 px Display
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 504  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 570                 6.8 inches, 1080 x 2460 px Display
# 613        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682  6.8 inches, 1080 x 2460 px Display with Punch ...
# 721        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 844                     4 inches, 480 x 640 px Display
# 894                 7.2 inches, 1440 x 1920 px Display
# 993                   8 inches, 2200 x 2480 px Display
#
#                                                 camera  \
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 306       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 504       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 570  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 721  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 844                      5 MP Rear & 2 MP Front Camera
# 894  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 993                             48 MP Quad Rear Camera
#
#                                    card                                  os
# 159           Memory Card Not Supported           Memory Card Not Supported
# 306           Memory Card Not Supported           Memory Card Not Supported
# 322  Memory Card Supported, upto 256 GB  Memory Card Supported, upto 256 GB
# 365           Memory Card Not Supported           Memory Card Not Supported
# 392           Memory Card Not Supported           Memory Card Not Supported
# 504           Memory Card Not Supported           Memory Card Not Supported
# 570     Memory Card (Hybrid), upto 2 TB     Memory Card (Hybrid), upto 2 TB
# 613                Memory Card (Hybrid)                Memory Card (Hybrid)
# 682     Memory Card (Hybrid), upto 2 TB     Memory Card (Hybrid), upto 2 TB
# 721           Memory Card Not Supported           Memory Card Not Supported
# 726   Memory Card (Hybrid), upto 256 GB   Memory Card (Hybrid), upto 256 GB
# 844  Memory Card Supported, upto 128 GB  Memory Card Supported, upto 128 GB
# 894  Memory Card Supported, upto 256 GB  Memory Card Supported, upto 256 GB
# 993   Memory Card (Hybrid), upto 256 GB   Memory Card (Hybrid), upto 256 GB

# %%
df1.loc[temp_df.index] = np.nan

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        287
# Android v11                        233
# No FM Radio                        180
# Android v10                         58
# Android v13                         45
# Bluetooth                           34
# Android v9.0 (Pie)                  27
# Android v10.0                       22
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# iOS v13                              3
# EMUI v12                             2
# Android v6.0 (Marshmallow)           2
# Android v5.1.1 (Lollipop)            2
# Harmony v2.0                         2
# iOS v14.0                            2
# RTOS (Series 30+)                    1
# Android v7.1 (Nougat)                1
# Android                              1
# HarmonyOS v2.0                       1
# Hongmeng OS v4.0                     1
# iOS v12.3                            1
# Pragati OS (Powered by Android)      1
# Hongmeng OS v3.0                     1
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v17                              1
# Android v12.1                        1
# iOS v13.0                            1
# HarmonyOS v2                         1
# Android v9 (Pie)                     1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['os'] == 'Bluetooth']
temp_df
# Out:
#      index                                           model     price  rating  \
# 18    20.0                                  OnePlus 10R 5G   32999.0    86.0
# 20    22.0                                     OnePlus 11R   39999.0    85.0
# 37    39.0                     Samsung Galaxy S22 Ultra 5G   91999.0     NaN
# 60    62.0                     Xiaomi Redmi Note 13 Pro 5G   17990.0    78.0
# 107  109.0                           Samsung Galaxy S22 5G   49999.0    86.0
# 109  111.0               OnePlus 10R 5G (12GB RAM + 256GB)   36999.0    87.0
# 112  114.0                            Xiaomi Redmi K50i 5G   22999.0    82.0
# 251  253.0                            Tecno Phantom X2 Pro   49999.0    89.0
# 257  259.0                      Samsung Galaxy S22 Plus 5G   64449.0    87.0
# 301  303.0             Xiaomi Redmi K50i (8GB RAM + 256GB)   25999.0    85.0
# 313  315.0  Samsung Galaxy S22 Ultra 5G (12GB RAM + 512GB)  118999.0     NaN
# 319  321.0                                     Honor X9 5G   16999.0    80.0
# 342  344.0                           Tecno Camon 19 Pro 5G   21999.0    82.0
# 399  401.0                                        itel P36    6490.0     NaN
# 453  455.0                                 Tecno Phantom X   25999.0    84.0
# 486  488.0                                   Nokia 8000 4G    6899.0     NaN
# 515  517.0                                  Google Pixel 5   36000.0    82.0
# 526  528.0                              Realme GT 2 Pro 5G   49959.0    89.0
# 534  536.0                       OnePlus 10R Prime Edition   35389.0    85.0
# 544  546.0         Samsung Galaxy S22 5G (8GB RAM + 256GB)   57999.0    87.0
# 638  640.0                              Tecno Camon 19 Pro   17990.0    81.0
# 641  643.0   Samsung Galaxy S22 Ultra 5G (8GB RAM + 128GB)   99990.0     NaN
# 644  646.0                                        Vivo Y10   12490.0    63.0
# 770  772.0           Realme GT 2 Pro 5G (12GB RAM + 256GB)   46999.0    89.0
# 774  776.0    Samsung Galaxy S22 Plus 5G (8GB RAM + 256GB)   88999.0    88.0
# 810  812.0                               Xiaomi Redmi K60i   28999.0    85.0
# 820  822.0                              Tecno Camon 19 Neo   14999.0    77.0
# 836  838.0                                    Vivo Y55s 5G   19990.0    79.0
# 858  860.0                                     Oppo Reno 5   29990.0    83.0
# 895  897.0                                  Tecno Camon 18   11499.0    75.0
# 896  898.0                             Tecno Phantom X Pro   22999.0    84.0
# 909  911.0                              Oppo Reno 5 Pro 5G   38700.0    84.0
# 933  935.0                          Tecno Camon 20 Premier   20999.0    79.0
# 947  949.0             Realme GT 2 Explorer Master Edition   40990.0    86.0
#
#                                                    sim  \
# 18             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 20             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 37             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 60   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 107            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 109            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 112     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 251            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 257            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 301     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 313            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 319            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 342            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 399                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 453                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 486                            Dual Sim, 3G, 4G, Wi-Fi
# 515            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 526            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 534            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 544            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 638                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 641            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 644                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 770            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 774            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 810  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR B...
# 820                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 836                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 858                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 895                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 896                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 909                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 933            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 947            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 18   Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 20   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 37      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 60           Dimensity 720, Octa Core, 2 GHz Processor
# 107     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 109  Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 112     Dimensity  8100, Octa Core, 2.85 GHz Processor
# 251      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 257     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 301     Dimensity  8100, Octa Core, 2.85 GHz Processor
# 313     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 319       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 342     Dimensity 810 5G, Octa Core, 2.4 GHz Processor
# 399  Spreadtrum  SC7731E, Quad Core, 1.3 GHz Processor
# 453           Helio G95, Octa Core, 2.05 GHz Processor
# 486      Snapdragon  210, Quad Core, 1.1 GHz Processor
# 515     Snapdragon 765G , Octa Core, 2.4 GHz Processor
# 526      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 534  Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# 544     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 638          Helio  G96, Octa Core, 2.05 GHz Processor
# 641     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 644            Helio P35, Octa Core, 2.3 GHz Processor
# 770      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 774     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 810      Dimensity  8200, Octa Core, 3.1 GHz Processor
# 820             Helio  G85, Octa Core, 2 GHz Processor
# 836     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 858    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 895             Helio  G88, Octa Core, 2 GHz Processor
# 896           Helio G95, Octa Core, 2.05 GHz Processor
# 909      Dimensity 1000+, Octa Core, 2.6 GHz Processor
# 933    Dimensity  700 5G, Octa Core, 2.2 GHz Processor
# 947   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
#
#                            ram                                   battery  \
# 18    8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 20    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 37   12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 60    6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 107   8 GB RAM, 128 GB inbuilt   3700 mAh Battery with 25W Fast Charging
# 109  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 112   6 GB RAM, 128 GB inbuilt   5080 mAh Battery with 67W Fast Charging
# 251  12 GB RAM, 256 GB inbuilt   5160 mAh Battery with 45W Fast Charging
# 257   8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 45W Fast Charging
# 301   8 GB RAM, 256 GB inbuilt   5080 mAh Battery with 67W Fast Charging
# 313  12 GB RAM, 512 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 319   8 GB RAM, 128 GB inbuilt   4800 mAh Battery with 66W Fast Charging
# 342   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 399    1 GB RAM, 16 GB inbuilt                          5000 mAh Battery
# 453   8 GB RAM, 256 GB inbuilt   4700 mAh Battery with 33W Fast Charging
# 486   512 MB RAM, 4 GB inbuilt                          1500 mAh Battery
# 515   8 GB RAM, 128 GB inbuilt   4080 mAh Battery with 18W Fast Charging
# 526   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 65W Fast Charging
# 534   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 544   8 GB RAM, 256 GB inbuilt   3700 mAh Battery with 25W Fast Charging
# 638   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 641   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 644   4 GB RAM, 128 GB inbuilt                          5000 mAh Battery
# 770  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 65W Fast Charging
# 774   8 GB RAM, 256 GB inbuilt   4500 mAh Battery with 45W Fast Charging
# 810   8 GB RAM, 128 GB inbuilt  5080 mAh Battery with 120W Fast Charging
# 820   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 836   8 GB RAM, 128 GB inbuilt   6000 mAh Battery with 18W Fast Charging
# 858   8 GB RAM, 128 GB inbuilt   4300 mAh Battery with 65W Fast Charging
# 895   4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 896   8 GB RAM, 256 GB inbuilt   5000 mAh Battery with 44W Fast Charging
# 909   8 GB RAM, 128 GB inbuilt   4350 mAh Battery with 65W Fast Charging
# 933   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 947   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 100W Fast Charging
#
#                                                display  \
# 18   6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 20   6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 37   6.8 inches, 1440 x 3080 px, 120 Hz Display wit...
# 60   6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 107  6.1 inches, 1080 x 2340 px, 120 Hz Display wit...
# 109  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 112  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 251  6.8 inches, 1080 x 2400 px, 120 Hz Display wit...
# 257  6.6 inches, 1080 x 2340 px, 120 Hz Display wit...
# 301  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 313  6.8 inches, 1440 x 3080 px, 120 Hz Display wit...
# 319                6.81 inches, 1080 x 2388 px Display
# 342  6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 399  6.5 inches, 1600 x 720 px Display with Water D...
# 453  6.7 inches, 1080 x 2340 px, 90 Hz Display with...
# 486                   2.8 inches, 240 x 320 px Display
# 515  6 inches, 1080 x 2340 px, 90 Hz Display with P...
# 526  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 534  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 544  6.1 inches, 1080 x 2340 px, 120 Hz Display wit...
# 638  6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 641  6.8 inches, 1440 x 3080 px, 120 Hz Display wit...
# 644  6.51 inches, 720 x 1600 px Display with Water ...
# 770  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 774  6.6 inches, 1080 x 2340 px, 120 Hz Display wit...
# 810  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 820  6.8 inches, 1080 x 2400 px, 90 Hz Display with...
# 836  6.58 inches, 1080 x 2408 px Display with Water...
# 858  6.43 inches, 1080 x 2400 px Display with Punch...
# 895  6.8 inches, 1080 x 2460 px, 90 Hz Display with...
# 896  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 909  6.53 inches, 1080 x 2400 px, 90 Hz Display wit...
# 933  6.83 inches, 1080 x 2460 px, 120 Hz Display wi...
# 947  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                                 camera  \
# 18   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 20   50 MP + 12 MP + 2 MP Triple Rear & 16 MP Front...
# 37               108 MP Quad Rear & 40 MP Front Camera
# 60   108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 107  50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 109  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 112  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 251  50 MP + 50 MP + 13 MP Triple Rear & 32 MP Fron...
# 257  50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 301  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 313              108 MP Quad Rear & 40 MP Front Camera
# 319  48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 342  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 399        8 MP + 0.3 MP Dual Rear & 8 MP Front Camera
# 453  50 MP + 13 MP + 8 MP Triple Rear & 48 MP + 8 M...
# 486                                   2 MP Rear Camera
# 515      16 MP + 12.2 MP Dual Rear & 8 MP Front Camera
# 526  50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 534  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 544  50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 638  64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 641              108 MP Quad Rear & 40 MP Front Camera
# 644         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 770  50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 774  50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 810  50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 820      48 MP + 2 MP Triple Rear & 32 MP Front Camera
# 836         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 858               64 MP Quad Rear & 32 MP Front Camera
# 895  48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 896   50 MP Quad Rear & 48 MP + 8 MP Dual Front Camera
# 909               64 MP Quad Rear & 32 MP Front Camera
# 933  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 947     50 MP + 50 MP Triple Rear & 16 MP Front Camera
#
#                           card         os
# 18   Memory Card Not Supported  Bluetooth
# 20   Memory Card Not Supported  Bluetooth
# 37   Memory Card Not Supported  Bluetooth
# 60   Memory Card Not Supported  Bluetooth
# 107  Memory Card Not Supported  Bluetooth
# 109  Memory Card Not Supported  Bluetooth
# 112  Memory Card Not Supported  Bluetooth
# 251  Memory Card Not Supported  Bluetooth
# 257  Memory Card Not Supported  Bluetooth
# 301  Memory Card Not Supported  Bluetooth
# 313  Memory Card Not Supported  Bluetooth
# 319  Memory Card Not Supported  Bluetooth
# 342  Memory Card Not Supported  Bluetooth
# 399  Memory Card Not Supported  Bluetooth
# 453  Memory Card Not Supported  Bluetooth
# 486      Memory Card Supported  Bluetooth
# 515  Memory Card Not Supported  Bluetooth
# 526  Memory Card Not Supported  Bluetooth
# 534  Memory Card Not Supported  Bluetooth
# 544  Memory Card Not Supported  Bluetooth
# 638  Memory Card Not Supported  Bluetooth
# 641  Memory Card Not Supported  Bluetooth
# 644  Memory Card Not Supported  Bluetooth
# 770  Memory Card Not Supported  Bluetooth
# 774  Memory Card Not Supported  Bluetooth
# 810  Memory Card Not Supported  Bluetooth
# 820  Memory Card Not Supported  Bluetooth
# 836  Memory Card Not Supported  Bluetooth
# 858  Memory Card Not Supported  Bluetooth
# 895  Memory Card Not Supported  Bluetooth
# 896  Memory Card Not Supported  Bluetooth
# 909  Memory Card Not Supported  Bluetooth
# 933  Memory Card Not Supported  Bluetooth
# 947  Memory Card Not Supported  Bluetooth

# %%
df1.loc[temp_df.index,'os'] = np.nan

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        287
# Android v11                        233
# No FM Radio                        180
# Android v10                         58
# Android v13                         45
# Android v9.0 (Pie)                  27
# Android v10.0                       22
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# iOS v13                              3
# EMUI v12                             2
# Android v6.0 (Marshmallow)           2
# Android v5.1.1 (Lollipop)            2
# Harmony v2.0                         2
# iOS v14.0                            2
# RTOS (Series 30+)                    1
# Android v7.1 (Nougat)                1
# Android                              1
# HarmonyOS v2.0                       1
# Hongmeng OS v4.0                     1
# iOS v12.3                            1
# Pragati OS (Powered by Android)      1
# Hongmeng OS v3.0                     1
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v17                              1
# Android v12.1                        1
# iOS v13.0                            1
# HarmonyOS v2                         1
# Android v9 (Pie)                     1
# Name: count, dtype: int64

# %%
#model column

#extracting brand names
b = df1['model'].str.split(' ').str.get(0)
b
# Out:
# 0        OnePlus
# 1        OnePlus
# 2        Samsung
# 3       Motorola
# 4         Realme
#           ...
# 1015    Motorola
# 1016       Honor
# 1017        POCO
# 1018    Motorola
# 1019     Samsung
# Name: model, Length: 982, dtype: object

# %%
df1.insert(1,'brand_name',b)

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    OnePlus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    OnePlus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
df1['brand_name'] = df1['brand_name'].str.lower()

# %%
#sim column


#will create three columns 5g, nfc, IR Blaster

has_5g = df1['sim'].str.contains('5G')
has_nfc = df1['sim'].str.contains('NFC')
has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6,'has_5g',has_5g)
df1.insert(7,'has_nfc',has_nfc)
df1.insert(8,'has_ir_blaster',has_ir_blaster)

# %%
#processor column

df1['processor']
# Out:
# 0       Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2             Exynos 1330, Octa Core, 2.4 GHz Processor
# 3         Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4          Dimensity 1080, Octa Core, 2.6 GHz Processor
#                              ...
# 1015      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016     Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017      Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                                Octa Core Processor
# Name: processor, Length: 982, dtype: object

# %%
processor_name = df1['processor'].str.split(',').str.get(0)

# %%
num_cores = df1['processor'].str.split(',').str.get(1)

# %%
processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(10,'processor_name',processor_name)
df1.insert(11,'num_cores',num_cores)
df1.insert(12,'processor_speed',processor_speed)

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#     num_cores     processor_speed                        ram  \
# 0   Octa Core   3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1   Octa Core   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
temp_df = df1[df1['processor_name'].str.contains('Core', na=False)][['processor_name', 'num_cores',	'processor_speed']].shift(1,axis=1)

# %%
df1.loc[temp_df.index,['processor_name', 'num_cores',	'processor_speed']] = temp_df.values

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Helio P35             30
# Snapdragon 695        29
# Dimensity 700 5G      29
# Snapdragon 8+ Gen1    25
# Snapdragon 680        24
#                       ..
# Helio MT6580           1
# Helio  G95             1
# Unisoc T606            1
# Helio  P35             1
# Google  Tensor 3       1
# Name: count, Length: 215, dtype: int64

# %%
df1.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11,'processor_brand',processor_brand)

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand   num_cores     processor_speed                        ram  \
# 0      snapdragon   Octa Core   3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1      snapdragon   Octa Core   2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    886
# Hexa Core     39
# Quad Core     36
# Name: count, dtype: int64

# %%
#processor_speed


#space r basis e eta split hoy nai
#df1['processor_speed'].str.strip().str.split(' ').str.get(0)
df1['processor_speed'].str.strip().str.split(' ').str.get(0)[0]
# Out:
# '3.2\u2009GHz'

# %%
#because space was replaced with a unicode which represents thin space.

df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
# ram column

df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt     260
# 6 GB RAM, 128 GB inbuilt     190
# 4 GB RAM, 64 GB inbuilt      143
# 8 GB RAM, 256 GB inbuilt      69
# 12 GB RAM, 256 GB inbuilt     68
# 4 GB RAM, 128 GB inbuilt      62
# 3 GB RAM, 32 GB inbuilt       37
# 6 GB RAM, 64 GB inbuilt       29
# 2 GB RAM, 32 GB inbuilt       24
# 3 GB RAM, 64 GB inbuilt       15
# 12 GB RAM, 512 GB inbuilt     10
# 6 GB RAM, 256 GB inbuilt       7
# 16 GB RAM, 256 GB inbuilt      6
# 4 GB RAM, 32 GB inbuilt        6
# 1 GB RAM, 16 GB inbuilt        6
# 6 GB RAM, 1 TB inbuilt         4
# 2 GB RAM, 64 GB inbuilt        4
# 12 GB RAM, 128 GB inbuilt      4
# 6 GB RAM, 512 GB inbuilt       4
# 4 GB RAM, 256 GB inbuilt       3
# 2 GB RAM, 16 GB inbuilt        3
# 16 GB RAM, 512 GB inbuilt      2
# 64 GB inbuilt                  2
# 3 GB RAM, 16 GB inbuilt        2
# 1 GB RAM, 8 GB inbuilt         1
# 4 GB RAM, 512 GB inbuilt       1
# 18 GB RAM, 512 GB inbuilt      1
# 64 MB RAM, 128 MB inbuilt      1
# 512 MB RAM, 4 GB inbuilt       1
# 512 GB inbuilt                 1
# 18 GB RAM, 256 GB inbuilt      1
# 12 GB RAM, 1 TB inbuilt        1
# Name: count, dtype: int64

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(16,'ram_capacity',ram_capacity)

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(17,'internal_memory',internal_memory)

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor  ...  num_cores  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...  Octa Core
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...  Octa Core
#
#   processor_speed                        ram  \
# 0             3.2  12 GB RAM, 256 GB inbuilt
# 1             2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery ram_capacity internal_memory  \
# 0  5000 mAh Battery with 100W Fast Charging           12             256
# 1   5000 mAh Battery with 33W Fast Charging            6             128
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12
#
# [2 rows x 22 columns]

# %%
df1['ram_capacity'] = df1['ram_capacity'].astype(float)

# %%
temp_df = df1[df1['ram_capacity'] > 18]
temp_df
#439(4),483(12),762(4)
# Out:
#      index brand_name                             model     price  rating  \
# 439  441.0      apple            Apple iPhone SE 3 2022   43900.0     NaN
# 483  485.0     huawei  Huawei Mate 50 RS Porsche Design  239999.0    81.0
# 486  488.0      nokia                     Nokia 8000 4G    6899.0     NaN
# 627  629.0      nokia                      Nokia 225 4G    3589.0     NaN
# 762  764.0      apple                 Apple iPhone SE 4   49990.0    60.0
#
#                                                  sim has_5g has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster  False    True
# 486                          Dual Sim, 3G, 4G, Wi-Fi  False   False
# 627                          Dual Sim, 3G, 4G, VoLTE  False   False
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
#
#     has_ir_blaster                                         processor  ...  \
# 439          False        Bionic  A15, Hexa Core, 3.22 GHz Processor  ...
# 483           True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 486          False     Snapdragon  210, Quad Core, 1.1 GHz Processor  ...
# 627          False                                       Unisoc T117  ...
# 762          False        Bionic  A15, Hexa Core, 3.22 GHz Processor  ...
#
#      num_cores processor_speed                        ram  \
# 439  Hexa Core            3.22              64 GB inbuilt
# 483  Octa Core            3.20             512 GB inbuilt
# 486  Quad Core            1.10   512 MB RAM, 4 GB inbuilt
# 627        NaN             NaN  64 MB RAM, 128 MB inbuilt
# 762  Hexa Core            3.22              64 GB inbuilt
#
#                                      battery ram_capacity internal_memory  \
# 439                                     None         64.0             NaN
# 483  4700 mAh Battery with 66W Fast Charging        512.0             NaN
# 486                         1500 mAh Battery        512.0               4
# 627                         1150 mAh Battery         64.0             128
# 762                                     None         64.0             NaN
#
#                                          display  \
# 439            4.7 inches, 750 x 1334 px Display
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 486             2.8 inches, 240 x 320 px Display
# 627             2.4 inches, 240 x 320 px Display
# 762            6.1 inches, 750 x 1580 px Display
#
#                                                 camera  \
# 439                     12 MP Rear & 7 MP Front Camera
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 486                                   2 MP Rear Camera
# 627                                 0.3 MP Rear Camera
# 762                  12 MP Rear & 10.8 MP Front Camera
#
#                                   card                 os
# 439          Memory Card Not Supported            iOS v15
# 483  Memory Card (Hybrid), upto 256 GB   Hongmeng OS v3.0
# 486              Memory Card Supported                NaN
# 627  Memory Card Supported, upto 32 GB  RTOS (Series 30+)
# 762          Memory Card Not Supported            iOS v16
#
# [5 rows x 22 columns]

# %%
df1.drop([486,627],inplace=True)

# %%
temp_df = df1[df1['ram_capacity'] > 18]
temp_df
# Out:
#      index brand_name                             model     price  rating  \
# 439  441.0      apple            Apple iPhone SE 3 2022   43900.0     NaN
# 483  485.0     huawei  Huawei Mate 50 RS Porsche Design  239999.0    81.0
# 762  764.0      apple                 Apple iPhone SE 4   49990.0    60.0
#
#                                                  sim has_5g has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster  False    True
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
#
#     has_ir_blaster                                         processor  ...  \
# 439          False        Bionic  A15, Hexa Core, 3.22 GHz Processor  ...
# 483           True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 762          False        Bionic  A15, Hexa Core, 3.22 GHz Processor  ...
#
#      num_cores processor_speed             ram  \
# 439  Hexa Core            3.22   64 GB inbuilt
# 483  Octa Core            3.20  512 GB inbuilt
# 762  Hexa Core            3.22   64 GB inbuilt
#
#                                      battery ram_capacity internal_memory  \
# 439                                     None         64.0             NaN
# 483  4700 mAh Battery with 66W Fast Charging        512.0             NaN
# 762                                     None         64.0             NaN
#
#                                          display  \
# 439            4.7 inches, 750 x 1334 px Display
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 762            6.1 inches, 750 x 1580 px Display
#
#                                                 camera  \
# 439                     12 MP Rear & 7 MP Front Camera
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
#
#                                   card                os
# 439          Memory Card Not Supported           iOS v15
# 483  Memory Card (Hybrid), upto 256 GB  Hongmeng OS v3.0
# 762          Memory Card Not Supported           iOS v16
#
# [3 rows x 22 columns]

# %%
temp_df.loc[temp_df.index,'ram_capacity'] = [4,12,4]

# %%
temp_df = df1[df1['ram_capacity'] > 18]

# %%
temp_df[['ram_capacity',	'internal_memory']].shift(1,axis=1)
# Out:
#      ram_capacity  internal_memory
# 439           NaN             64.0
# 483           NaN            512.0
# 762           NaN             64.0

# %%
df1.loc[temp_df.index, ['ram_capacity', 'internal_memory']] = df1.loc[temp_df.index, ['ram_capacity', 'internal_memory']].shift(1, axis=1)

# %%
df1.loc[temp_df.index,'ram_capacity'] = [4,12,4]

# %%
df1.loc[[439, 483, 762]]
# Out:
#      index brand_name                             model     price  rating  \
# 439  441.0      apple            Apple iPhone SE 3 2022   43900.0     NaN
# 483  485.0     huawei  Huawei Mate 50 RS Porsche Design  239999.0    81.0
# 762  764.0      apple                 Apple iPhone SE 4   49990.0    60.0
#
#                                                  sim has_5g has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster  False    True
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
#
#     has_ir_blaster                                         processor  ...  \
# 439          False        Bionic  A15, Hexa Core, 3.22 GHz Processor  ...
# 483           True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 762          False        Bionic  A15, Hexa Core, 3.22 GHz Processor  ...
#
#      num_cores processor_speed             ram  \
# 439  Hexa Core            3.22   64 GB inbuilt
# 483  Octa Core            3.20  512 GB inbuilt
# 762  Hexa Core            3.22   64 GB inbuilt
#
#                                      battery ram_capacity internal_memory  \
# 439                                     None          4.0            64.0
# 483  4700 mAh Battery with 66W Fast Charging         12.0           512.0
# 762                                     None          4.0            64.0
#
#                                          display  \
# 439            4.7 inches, 750 x 1334 px Display
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 762            6.1 inches, 750 x 1580 px Display
#
#                                                 camera  \
# 439                     12 MP Rear & 7 MP Front Camera
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
#
#                                   card                os
# 439          Memory Card Not Supported           iOS v15
# 483  Memory Card (Hybrid), upto 256 GB  Hongmeng OS v3.0
# 762          Memory Card Not Supported           iOS v16
#
# [3 rows x 22 columns]

# %%
#internal_memory column

df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128.0    516
# 64.0     193
# 256.0    154
# 32.0      67
# 512.0     19
# 16.0      11
# 1.0        5
# 8.0        1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['internal_memory'] == 1]
temp_df
# Out:
#      index brand_name                                     model     price  \
# 290  292.0      apple             Apple iPhone 14 Pro Max (1TB)  182999.0
# 781  783.0      apple             Apple iPhone 13 Pro Max (1TB)  179900.0
# 814  816.0      apple                 Apple iPhone 14 Pro (1TB)  172999.0
# 943  945.0    samsung  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980.0
# 961  963.0      apple                 Apple iPhone 13 Pro (1TB)  147900.0
#
#      rating                                      sim has_5g has_nfc  \
# 290    78.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 781    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 814    77.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 943     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 961    84.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
#
#     has_ir_blaster                                          processor  ...  \
# 290          False                   Bionic  A16, Hexa Core Processor  ...
# 781          False          Bionic A15, Hexa Core, 3.22 GHz Processor  ...
# 814          False                   Bionic  A16, Hexa Core Processor  ...
# 943          False  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 961          False          Bionic A15, Hexa Core, 3.22 GHz Processor  ...
#
#      num_cores processor_speed                      ram  \
# 290  Hexa Core             NaN   6 GB RAM, 1 TB inbuilt
# 781  Hexa Core            3.22   6 GB RAM, 1 TB inbuilt
# 814  Hexa Core             NaN   6 GB RAM, 1 TB inbuilt
# 943  Octa Core            3.20  12 GB RAM, 1 TB inbuilt
# 961  Hexa Core            3.22   6 GB RAM, 1 TB inbuilt
#
#                                      battery ram_capacity internal_memory  \
# 290      4323 mAh Battery with Fast Charging          6.0             1.0
# 781      4352 mAh Battery with Fast Charging          6.0             1.0
# 814      3200 mAh Battery with Fast Charging          6.0             1.0
# 943  4400 mAh Battery with 25W Fast Charging         12.0             1.0
# 961      3095 mAh Battery with Fast Charging          6.0             1.0
#
#                                                display  \
# 290         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 781  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 814         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 943  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 961  6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
#
#                                                 camera  \
# 290  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 781  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 814  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 943  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 961  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card           os
# 290  Memory Card Not Supported      iOS v16
# 781  Memory Card Not Supported      iOS v15
# 814  Memory Card Not Supported      iOS v16
# 943  Memory Card Not Supported  Android v12
# 961  Memory Card Not Supported    iOS v15.0
#
# [5 rows x 22 columns]

# %%
df1.loc[temp_df.index,'internal_memory'] = 1024

# %%
# battery column

battery_capacity = df1['battery'].str.split('with').str.get(0).str.split('mAh').str.get(0).astype(float)

# %%
df1.insert(16,'battery_capacity',battery_capacity)

# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df1.insert(17,'fast_charging',fast_charging)

# %%
def fast_charging_extractor(item):

  if type(item) == list:
    if len(item) == 1:
      return item[0]
    else:
      return 0
  else:
    return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)

# %%
df1.insert(21,'screen_size',screen_size)

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df1.insert(22,'resolution',resolution)

# %%
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x: 60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(22,'refresh_rate',refresh_rate)

# %%
def camera_extractor(text):

  if 'Quad' in text:
    return '4'
  elif 'Triple' in text:
    return '3'
  elif 'Dual' in text:
    return '2'
  elif 'Missing' in text:
    return 'Missing'
  else:
    return '1'

# %%
df1['camera'] = df1['camera'].fillna('')
num_rear_cameras = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
df1.insert(25,'num_rear_cameras',num_rear_cameras)

# %%
num_front_cameras = df1['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_extractor)

# %%
df1.insert(26,'num_front_cameras',num_front_cameras)

# %%
df1[df1['num_front_cameras'] == 'Missing']
# Out:
#        index brand_name                model     price  rating  \
# 69      71.0       oppo     Oppo Find N Fold   99990.0     NaN
# 159      NaN        NaN                  NaN       NaN     NaN
# 306      NaN        NaN                  NaN       NaN     NaN
# 322      NaN        NaN                  NaN       NaN     NaN
# 365      NaN        NaN                  NaN       NaN     NaN
# 392      NaN        NaN                  NaN       NaN     NaN
# 462    464.0     xiaomi  Xiaomi Mi Mix Alpha  199990.0     NaN
# 504      NaN        NaN                  NaN       NaN     NaN
# 570      NaN        NaN                  NaN       NaN     NaN
# 613      NaN        NaN                  NaN       NaN     NaN
# 682      NaN        NaN                  NaN       NaN     NaN
# 721      NaN        NaN                  NaN       NaN     NaN
# 726      NaN        NaN                  NaN       NaN     NaN
# 844      NaN        NaN                  NaN       NaN     NaN
# 894      NaN        NaN                  NaN       NaN     NaN
# 993      NaN        NaN                  NaN       NaN     NaN
# 1012  1014.0       itel            itel A23s    4787.0     NaN
#
#                                           sim has_5g has_nfc has_ir_blaster  \
# 69    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 159                                       NaN    NaN     NaN            NaN
# 306                                       NaN    NaN     NaN            NaN
# 322                                       NaN    NaN     NaN            NaN
# 365                                       NaN    NaN     NaN            NaN
# 392                                       NaN    NaN     NaN            NaN
# 462        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
# 504                                       NaN    NaN     NaN            NaN
# 570                                       NaN    NaN     NaN            NaN
# 613                                       NaN    NaN     NaN            NaN
# 682                                       NaN    NaN     NaN            NaN
# 721                                       NaN    NaN     NaN            NaN
# 726                                       NaN    NaN     NaN            NaN
# 844                                       NaN    NaN     NaN            NaN
# 894                                       NaN    NaN     NaN            NaN
# 993                                       NaN    NaN     NaN            NaN
# 1012                  Dual Sim, 3G, 4G, Wi-Fi  False   False          False
#
#                                               processor  ... internal_memory  \
# 69    Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor  ...           256.0
# 159                                                 NaN  ...             NaN
# 306                                                 NaN  ...             NaN
# 322                                                 NaN  ...             NaN
# 365                                                 NaN  ...             NaN
# 392                                                 NaN  ...             NaN
# 462      Snapdragon 855+, Octa Core, 2.96 GHz Processor  ...           512.0
# 504                                                 NaN  ...             NaN
# 570                                                 NaN  ...             NaN
# 613                                                 NaN  ...             NaN
# 682                                                 NaN  ...             NaN
# 721                                                 NaN  ...             NaN
# 726                                                 NaN  ...             NaN
# 844                                                 NaN  ...             NaN
# 894                                                 NaN  ...             NaN
# 993                                                 NaN  ...             NaN
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor  ...            32.0
#
#                                                 display screen_size  \
# 69    7.1 inches, 1792 x 1920 px, 120 Hz Display wit...        7.10
# 159                                                 NaN         NaN
# 306                                                 NaN         NaN
# 322                                                 NaN         NaN
# 365                                                 NaN         NaN
# 392                                                 NaN         NaN
# 462                 7.92 inches, 2088 x 2250 px Display        7.92
# 504                                                 NaN         NaN
# 570                                                 NaN         NaN
# 613                                                 NaN         NaN
# 682                                                 NaN         NaN
# 721                                                 NaN         NaN
# 726                                                 NaN         NaN
# 844                                                 NaN         NaN
# 894                                                 NaN         NaN
# 993                                                 NaN         NaN
# 1012                     5 inches, 854 x 480 px Display        5.00
#
#       refresh_rate    resolution                                     camera  \
# 69             120  1792 x 1920              Foldable Display, Dual Display
# 159             60           NaN
# 306             60           NaN
# 322             60           NaN
# 365             60           NaN
# 392             60           NaN
# 462             60  2088 x 2250   108 MP + 20 MP + 12 MP Triple Rear Camera
# 504             60           NaN
# 570             60           NaN
# 613             60           NaN
# 682             60           NaN
# 721             60           NaN
# 726             60           NaN
# 844             60           NaN
# 894             60           NaN
# 993             60           NaN
# 1012            60    854 x 480                            2 MP Rear Camera
#
#       num_rear_cameras  num_front_cameras                       card  \
# 69                   2            Missing  Memory Card Not Supported
# 159                  1            Missing                        NaN
# 306                  1            Missing                        NaN
# 322                  1            Missing                        NaN
# 365                  1            Missing                        NaN
# 392                  1            Missing                        NaN
# 462                  3            Missing  Memory Card Not Supported
# 504                  1            Missing                        NaN
# 570                  1            Missing                        NaN
# 613                  1            Missing                        NaN
# 682                  1            Missing                        NaN
# 721                  1            Missing                        NaN
# 726                  1            Missing                        NaN
# 844                  1            Missing                        NaN
# 894                  1            Missing                        NaN
# 993                  1            Missing                        NaN
# 1012                 1            Missing  Memory Card Not Supported
#
#                os
# 69    Android v12
# 159           NaN
# 306           NaN
# 322           NaN
# 365           NaN
# 392           NaN
# 462   Android v10
# 504           NaN
# 570           NaN
# 613           NaN
# 682           NaN
# 721           NaN
# 726           NaN
# 844           NaN
# 894           NaN
# 993           NaN
# 1012  No FM Radio
#
# [17 rows x 29 columns]

# %%
#to display all columns

pd.set_option('display.max_columns',None)

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
#
#   num_front_cameras                             card           os
# 0                 1        Memory Card Not Supported  Android v13
# 1                 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
temp_df = df1[df1['camera'] == 'Foldable Display, Dual Display']

# %%
df1.loc[temp_df.index, 'camera'] = '50 MP'

# %%
df1['primary_camera_rear'] = df1['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1['primary_camera_front'] = df1['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1[df1['card'] == 'Memory Card (Hybrid)']
# Out:
#      index brand_name                                      model    price  \
# 25    27.0    samsung                   Samsung Galaxy S20 FE 5G  31239.0
# 80    82.0   motorola                       Motorola Moto G72 4G  15999.0
# 147  149.0    samsung                      Samsung Galaxy M34 5G  16999.0
# 151  153.0   motorola                          Motorola Moto G52  11999.0
# 178  180.0       vivo                                Vivo Y75 5G  21990.0
# 204  206.0   motorola        Motorola Moto G52 (6GB RAM + 128GB)  12999.0
# 248  250.0   motorola                          Motorola Moto G73  25999.0
# 254  256.0     xiaomi                Xiaomi Redmi Note 11 Pro 5G  17990.0
# 281  283.0       vivo                               Vivo V23e 5G  21994.0
# 305  307.0     xiaomi                    Xiaomi Mi 11 Lite NE 5G  21890.0
# 441  443.0       poco                                Poco X3 Pro  19650.0
# 470  472.0     xiaomi  Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)  22999.0
# 487  489.0       sony                           Sony Xperia 5 II  69990.0
# 489  491.0       sony        Sony Xperia 1 IV (12GB RAM + 512GB)  92980.0
# 513  515.0     realme                               Realme Q5 5G  14990.0
# 580  582.0      nokia                                  Nokia G60  28498.0
# 602  604.0       vivo                                   Vivo V21  24999.0
# 626  628.0       vivo                                Vivo V21 5G  23994.0
# 629  631.0       sony                           Sony Xperia 1 II  69999.0
# 662  664.0       vivo                                  Vivo V25e  19990.0
# 680  682.0         lg                               LG Velvet 5G  54999.0
# 696  698.0      honor                              Honor Play 30   9999.0
# 698  700.0       sony                        Sony Xperia 5 IV 5G  82199.0
# 720  722.0       vivo                                  Vivo V21s  29999.0
# 767  769.0   motorola                       Motorola Moto G52 5G  16999.0
# 860  862.0       sony                          Sony Xperia 10 II  27999.0
# 875  877.0     huawei                            Huawei Nova Y61  21990.0
# 939  941.0        zte                               ZTE Axon 30S  19999.0
# 940  942.0      honor                                   Honor X6  13999.0
# 942  944.0        tcl                                  TCL Ion X   8990.0
#
#      rating                                                sim has_5g has_nfc  \
# 25     88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 80     83.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC  False    True
# 147    84.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 151    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC  False    True
# 178    82.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False
# 204    79.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC  False    True
# 248    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 254    81.0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster   True   False
# 281    84.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False
# 305    83.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...   True    True
# 441    82.0         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster  False   False
# 470    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...   True    True
# 487    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 489     NaN            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 513    78.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False
# 580    81.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 602    83.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi  False   False
# 626    85.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False
# 629    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 662    84.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi  False   False
# 680    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 696    68.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False
# 698    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 720    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 767    76.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 860    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC  False    True
# 875    63.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi  False   False
# 939    82.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True
# 940    71.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi  False   False
# 942    60.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi  False   False
#
#     has_ir_blaster                                        processor  \
# 25           False    Snapdragon 865, Octa Core, 2.84 GHz Processor
# 80           False         Helio  G99, Octa Core, 2.2 GHz Processor
# 147          False        Exynos 1200, Octa Core, 2.4 GHz Processor
# 151          False     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 178          False  Dimensity  700 5G, Octa Core, 2.2 GHz Processor
# 204          False     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 248          False      Dimensity 930, Octa Core, 2.2 GHz Processor
# 254           True     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 281          False  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 305           True  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 441           True    Snapdragon 860, Octa Core, 2.96 GHz Processor
# 470           True  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 487          False   Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 489          False    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 513          False     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 580          False    Snapdragon  695, Octa Core, 2.2 GHz Processor
# 602          False     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 626          False     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 629          False  Snapdragon  865 , Octa Core, 2.84 GHz Processor
# 662          False          Helio G99, Octa Core, 2.2 GHz Processor
# 680          False   Snapdragon  765G, Octa Core, 2.4 GHz Processor
# 696          False    Snapdragon 480+, Octa Core, 2.2 GHz Processor
# 698          False    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 720          False    Dimensity 800U , Octa Core, 2.4 GHz Processor
# 767          False     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 860          False      Snapdragon  665, Octa Core, 2 GHz Processor
# 875          False                              Octa Core Processor
# 939          False    Snapdragon 870 , Octa Core, 3.2 GHz Processor
# 940          False            Helio G25, Octa Core, 2 GHz Processor
# 942          False            Helio G25, Octa Core, 2 GHz Processor
#
#         processor_name processor_brand  num_cores  processor_speed  \
# 25      Snapdragon 865      snapdragon  Octa Core             2.84
# 80          Helio  G99           helio  Octa Core             2.20
# 147        Exynos 1200          exynos  Octa Core             2.40
# 151     Snapdragon 680      snapdragon  Octa Core             2.40
# 178  Dimensity  700 5G       dimensity  Octa Core             2.20
# 204     Snapdragon 680      snapdragon  Octa Core             2.40
# 248      Dimensity 930       dimensity  Octa Core             2.20
# 254     Snapdragon 695      snapdragon  Octa Core             2.20
# 281  Dimensity  810 5G       dimensity  Octa Core             2.40
# 305   Snapdragon  778G      snapdragon  Octa Core             2.40
# 441     Snapdragon 860      snapdragon  Octa Core             2.96
# 470   Snapdragon  778G      snapdragon  Octa Core             2.40
# 487     Snapdragon 865      snapdragon  Octa Core             2.84
# 489  Snapdragon 8 Gen1      snapdragon  Octa Core             3.00
# 513     Snapdragon 695      snapdragon  Octa Core             2.20
# 580    Snapdragon  695      snapdragon  Octa Core             2.20
# 602     Dimensity 800U       dimensity  Octa Core             2.40
# 626     Dimensity 800U       dimensity  Octa Core             2.40
# 629    Snapdragon  865      snapdragon  Octa Core             2.84
# 662          Helio G99           helio  Octa Core             2.20
# 680   Snapdragon  765G      snapdragon  Octa Core             2.40
# 696    Snapdragon 480+      snapdragon  Octa Core             2.20
# 698  Snapdragon 8 Gen1      snapdragon  Octa Core             3.00
# 720     Dimensity 800U       dimensity  Octa Core             2.40
# 767     Snapdragon 695      snapdragon  Octa Core             2.20
# 860    Snapdragon  665      snapdragon  Octa Core             2.00
# 875               None            None  Octa Core              NaN
# 939     Snapdragon 870      snapdragon  Octa Core             3.20
# 940          Helio G25           helio  Octa Core             2.00
# 942          Helio G25           helio  Octa Core             2.00
#
#                            ram                                    battery  \
# 25    8 GB RAM, 128 GB inbuilt        4500 mAh Battery with Fast Charging
# 80    6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 147   6 GB RAM, 128 GB inbuilt    6000 mAh Battery with 25W Fast Charging
# 151    4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 178   8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 18W Fast Charging
# 204   6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 248   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 30W Fast Charging
# 254    6 GB RAM, 64 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 281   8 GB RAM, 128 GB inbuilt    4050 mAh Battery with 44W Fast Charging
# 305   6 GB RAM, 128 GB inbuilt    4250 mAh Battery with 33W Fast Charging
# 441   6 GB RAM, 128 GB inbuilt    5160 mAh Battery with 33W Fast Charging
# 470   8 GB RAM, 128 GB inbuilt    4250 mAh Battery with 33W Fast Charging
# 487   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 21W Fast Charging
# 489  12 GB RAM, 512 GB inbuilt    5000 mAh Battery with 30W Fast Charging
# 513   6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 60W Fast Charging
# 580   6 GB RAM, 128 GB inbuilt    4500 mAh Battery with 20W Fast Charging
# 602   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 33W Fast Charging
# 626   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 33W Fast Charging
# 629   8 GB RAM, 256 GB inbuilt    4000 mAh Battery with 21W Fast Charging
# 662   8 GB RAM, 256 GB inbuilt    4500 mAh Battery with 44W Fast Charging
# 680   6 GB RAM, 128 GB inbuilt    4300 mAh Battery with 25W Fast Charging
# 696   4 GB RAM, 128 GB inbuilt                           5000 mAh Battery
# 698   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 30W Fast Charging
# 720   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 33W Fast Charging
# 767    4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 860   4 GB RAM, 128 GB inbuilt    3600 mAh Battery with 18W Fast Charging
# 875    4 GB RAM, 64 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 939   6 GB RAM, 128 GB inbuilt    4200 mAh Battery with 55W Fast Charging
# 940    4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 10W Fast Charging
# 942    3 GB RAM, 32 GB inbuilt    3000 mAh Battery with 10W Fast Charging
#
#      battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 25             4500.0              0           8.0            128.0
# 80             5000.0             33           6.0            128.0
# 147            6000.0             25           6.0            128.0
# 151            5000.0             33           4.0             64.0
# 178            5000.0             18           8.0            128.0
# 204            5000.0             33           6.0            128.0
# 248            5000.0             30           8.0            256.0
# 254            5000.0             67           6.0             64.0
# 281            4050.0             44           8.0            128.0
# 305            4250.0             33           6.0            128.0
# 441            5160.0             33           6.0            128.0
# 470            4250.0             33           8.0            128.0
# 487            4000.0             21           8.0            128.0
# 489            5000.0             30          12.0            512.0
# 513            5000.0             60           6.0            128.0
# 580            4500.0             20           6.0            128.0
# 602            4000.0             33           8.0            128.0
# 626            4000.0             33           8.0            128.0
# 629            4000.0             21           8.0            256.0
# 662            4500.0             44           8.0            256.0
# 680            4300.0             25           6.0            128.0
# 696            5000.0             -1           4.0            128.0
# 698            5000.0             30           8.0            256.0
# 720            4000.0             33           8.0            128.0
# 767            5000.0             33           4.0             64.0
# 860            3600.0             18           4.0            128.0
# 875            5000.0             22           4.0             64.0
# 939            4200.0             55           6.0            128.0
# 940            5000.0             10           4.0             64.0
# 942            3000.0             10           3.0             32.0
#
#                                                display  screen_size  \
# 25   6.5 inches, 1080 x 2400 px, 120 Hz Display wit...         6.50
# 80   6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 147  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...         6.50
# 151  6.6 inches, 2460 x 1080 px, 90 Hz Display with...         6.60
# 178  6.58 inches, 1080 x 2408 px Display with Water...         6.58
# 204  6.6 inches, 2460 x 1080 px, 90 Hz Display with...         6.60
# 248  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...         6.50
# 254  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...         6.67
# 281  6.44 inches, 1080 x 2400 px Display with Water...         6.44
# 305  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...         6.55
# 441  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...         6.67
# 470  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...         6.55
# 487         6.1 inches, 1080 x 2520 px, 120 Hz Display         6.10
# 489         6.5 inches, 1644 x 3840 px, 120 Hz Display         6.50
# 513  6.6 inches, 1080 x 2412 px, 120 Hz Display wit...         6.60
# 580  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...         6.58
# 602  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 626  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 629                 6.5 inches, 1644 x 3840 px Display         6.50
# 662  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 680  6.8 inches, 1080 x 2460 px Display with Water ...         6.80
# 696  6.5 inches, 720 x 1600 px Display with Water D...         6.50
# 698         6.1 inches, 1080 x 2520 px, 120 Hz Display         6.10
# 720  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 767  6.6 inches, 2460 x 1080 px, 90 Hz Display with...         6.60
# 860            6 inches, 1080 x 2520 px, 90 Hz Display         6.00
# 875  6.52 inches, 720 x 1600 px Display with Water ...         6.52
# 939         6.9 inches, 1080 x 2460 px, 120 Hz Display         6.90
# 940  6.5 inches, 720 x 1600 px Display with Water D...         6.50
# 942                    6 inches, 720 x 1440 px Display         6.00
#
#      refresh_rate    resolution  \
# 25            120  1080 x 2400
# 80            120  1080 x 2400
# 147           120  1080 x 2400
# 151            90  2460 x 1080
# 178            60  1080 x 2408
# 204            90  2460 x 1080
# 248           120  1080 x 2400
# 254           120  1080 x 2400
# 281            60  1080 x 2400
# 305            90  1080 x 2400
# 441           120  1080 x 2400
# 470            90  1080 x 2400
# 487           120  1080 x 2520
# 489           120  1644 x 3840
# 513           120  1080 x 2412
# 580           120  1080 x 2400
# 602            90  1080 x 2400
# 626            90  1080 x 2400
# 629            60  1644 x 3840
# 662            90  1080 x 2400
# 680            60  1080 x 2460
# 696            60   720 x 1600
# 698           120  1080 x 2520
# 720            90  1080 x 2400
# 767            90  2460 x 1080
# 860            90  1080 x 2520
# 875            60   720 x 1600
# 939           120  1080 x 2460
# 940            60   720 x 1600
# 942            60   720 x 1440
#
#                                                 camera num_rear_cameras  \
# 25   12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...                3
# 80   108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
# 147               64 MP Quad Rear & 32 MP Front Camera                4
# 151  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 178  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 204  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 248        50 MP + 8 MP Dual Rear & 16 MP Front Camera                2
# 254  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
# 281  50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 305  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...                3
# 441               48 MP Quad Rear & 20 MP Front Camera                4
# 470  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...                3
# 487  12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...                3
# 489               12 MP Quad Rear & 12 MP Front Camera                4
# 513  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 580  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...                3
# 602  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 626  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 629                12 MP Quad Rear & 8 MP Front Camera                4
# 662  64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...                3
# 680  48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...                3
# 696                     13 MP Rear & 5 MP Front Camera                1
# 698  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...                3
# 720  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 767  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 860  12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...                3
# 875       50 MP + 2 MP Triple Rear & 5 MP Front Camera                3
# 939               50 MP Quad Rear & 16 MP Front Camera                4
# 940  50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...                3
# 942                     13 MP Rear & 5 MP Front Camera                1
#
#     num_front_cameras                  card             os  \
# 25                  1  Memory Card (Hybrid)    Android v10
# 80                  1  Memory Card (Hybrid)    Android v12
# 147                 1  Memory Card (Hybrid)    Android v12
# 151                 1  Memory Card (Hybrid)    Android v12
# 178                 1  Memory Card (Hybrid)    Android v12
# 204                 1  Memory Card (Hybrid)    Android v12
# 248                 1  Memory Card (Hybrid)    Android v13
# 254                 1  Memory Card (Hybrid)    Android v11
# 281                 1  Memory Card (Hybrid)    Android v12
# 305                 1  Memory Card (Hybrid)    Android v11
# 441                 1  Memory Card (Hybrid)    Android v11
# 470                 1  Memory Card (Hybrid)    Android v11
# 487                 1  Memory Card (Hybrid)    Android v10
# 489                 1  Memory Card (Hybrid)    Android v12
# 513                 1  Memory Card (Hybrid)    Android v12
# 580                 1  Memory Card (Hybrid)    Android v12
# 602                 1  Memory Card (Hybrid)    Android v11
# 626                 1  Memory Card (Hybrid)    Android v11
# 629                 1  Memory Card (Hybrid)    Android v10
# 662                 1  Memory Card (Hybrid)    Android v12
# 680                 1  Memory Card (Hybrid)    Android v10
# 696                 1  Memory Card (Hybrid)    Android v11
# 698                 1  Memory Card (Hybrid)    Android v12
# 720                 1  Memory Card (Hybrid)    Android v12
# 767                 1  Memory Card (Hybrid)    Android v12
# 860                 1  Memory Card (Hybrid)  Android v10.0
# 875                 1  Memory Card (Hybrid)       EMUI v12
# 939                 1  Memory Card (Hybrid)    Android v12
# 940                 1  Memory Card (Hybrid)    Android v12
# 942                 1  Memory Card (Hybrid)        Android
#
#     primary_camera_rear primary_camera_front
# 25                   12                   32
# 80                  108                   16
# 147                  64                   32
# 151                  50                   16
# 178                  50                   16
# 204                  50                   16
# 248                  50                   16
# 254                 108                   16
# 281                  50                   44
# 305                  64                   20
# 441                  48                   20
# 470                  64                   20
# 487                  12                    8
# 489                  12                   12
# 513                  50                   16
# 580                  50                    8
# 602                  64                   44
# 626                  64                   44
# 629                  12                    8
# 662                  64                   32
# 680                  48                   16
# 696                  13                    5
# 698                  12                   12
# 720                  64                   44
# 767                  50                   16
# 860                  12                    8
# 875                  50                    5
# 939                  50                   16
# 940                  50                    5
# 942                  13                    5

# %%
df1.loc[temp_df.index, 'card'] = 'Not Specified'

# %%
df1.head(2)
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
#
#   num_front_cameras                             card           os  \
# 0                 1        Memory Card Not Supported  Android v13
# 1                 1  Memory Card (Hybrid), upto 1 TB  Android v12
#
#   primary_camera_rear primary_camera_front
# 0                  50                   16
# 1                  64                   16

# %%
df1['extended_memory'] = df1['card'].fillna('Not Specified').apply(
    lambda x: '0' if 'Not' in x else x.split('upto')
).str.get(-1).str.strip().str.replace('Memory Card Supported', 'Not Specified')

# %%
df1.head()
# Out:
#    index brand_name                      model    price  rating  \
# 0    2.0    oneplus              OnePlus 11 5G  54999.0    89.0
# 1    3.0    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0
# 2    4.0    samsung      Samsung Galaxy A14 5G  16499.0    75.0
# 3    5.0   motorola       Motorola Moto G62 5G  14999.0    81.0
# 4    6.0     realme         Realme 10 Pro Plus  24999.0    82.0
#
#                                        sim has_5g has_nfc has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC   True    True          False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi   True   False          False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
# 2   5000 mAh Battery with 15W Fast Charging            5000.0             15
# 3       5000 mAh Battery with Fast Charging            5000.0              0
# 4   5000 mAh Battery with 67W Fast Charging            5000.0             67
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
# 2           4.0             64.0
# 3           6.0            128.0
# 4           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
# 2            90  1080 x 2408
# 3           120  1080 x 2400
# 4           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...                3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
#
#   num_front_cameras                              card           os  \
# 0                 1         Memory Card Not Supported  Android v13
# 1                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2                 1  Memory Card Supported, upto 1 TB  Android v13
# 3                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 4                 1         Memory Card Not Supported  Android v13
#
#   primary_camera_rear primary_camera_front extended_memory
# 0                  50                   16               0
# 1                  64                   16            1 TB
# 2                  50                   13            1 TB
# 3                  50                   16            1 TB
# 4                 108                   16               0

# %%
df1[df1['os'].str.contains('Memory Card', na=False)]
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, processor_brand, num_cores, processor_speed, ram, battery, battery_capacity, fast_charging, ram_capacity, internal_memory, display, screen_size, refresh_rate, resolution, camera, num_rear_cameras, num_front_cameras, card, os, primary_camera_rear, primary_camera_front, extended_memory]
# Index: []

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        287
# Android v11                        233
# No FM Radio                        180
# Android v10                         58
# Android v13                         45
# Android v9.0 (Pie)                  27
# Android v10.0                       22
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# iOS v13                              3
# iOS v14.0                            2
# EMUI v12                             2
# Android v6.0 (Marshmallow)           2
# Android v5.1.1 (Lollipop)            2
# Harmony v2.0                         2
# Android v7.1 (Nougat)                1
# Android                              1
# HarmonyOS v2.0                       1
# Hongmeng OS v4.0                     1
# iOS v12.3                            1
# Pragati OS (Powered by Android)      1
# Hongmeng OS v3.0                     1
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v17                              1
# Android v12.1                        1
# iOS v13.0                            1
# HarmonyOS v2                         1
# Android v9 (Pie)                     1
# Name: count, dtype: int64

# %%
#export_df = df1.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])

# %%
#export_df.to_csv('smartphone_cleaned_v2.csv',index=False)
